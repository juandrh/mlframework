# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import make_scorer
from xgboost import XGBRegressor, DMatrix

import matplotlib.pyplot as plt
# %matplotlib inline            
import seaborn as sns

from time import time
import pprint
import joblib
from functools import partial

# Suppressing warnings because of skopt verbosity
import warnings
warnings.filterwarnings("ignore")

# Skopt functions
from skopt import BayesSearchCV
from skopt.callbacks import DeadlineStopper, DeltaYStopper
from skopt.space import Real, Categorical, Integer

# Model selection
from sklearn.model_selection import KFold

import optuna

# %%
df = pd.read_csv("../input/train_folds.csv")
df_test = pd.read_csv("../input/test.csv")
sample_submission = pd.read_csv("../input/sample_submission.csv")

df = df.drop(df[df['target'].lt(6)].index)
print(df.shape)



useful_features = [c for c in df.columns if c not in ("id", "target", "kfold")]
object_cols = [col for col in useful_features if 'cat' in col]
numerical_cols = [col for col in useful_features if 'cont' in col]
df_test = df_test[useful_features]

# target encoding
for col in object_cols:
    temp_df = []
    temp_test_feat = None
    for fold in range(5):
        xtrain =  df[df.kfold != fold].reset_index(drop=True)
        xvalid = df[df.kfold == fold].reset_index(drop=True)
        feat = xtrain.groupby(col)["target"].agg("mean")
        feat = feat.to_dict()
        xvalid.loc[:, f"tar_enc_{col}"] = xvalid[col].map(feat)
        temp_df.append(xvalid)
        if temp_test_feat is None:
            temp_test_feat = df_test[col].map(feat)
        else:
            temp_test_feat += df_test[col].map(feat)
    
    temp_test_feat /= 5
    df_test.loc[:, f"tar_enc_{col}"] = temp_test_feat
    df = pd.concat(temp_df)

useful_features = [c for c in df.columns if c not in ("id", "target", "kfold")]
object_cols = [col for col in useful_features if col.startswith("cat")]
df_test = df_test[useful_features]
# Out:
# (299628, 27)

# %%
def run(trial):

    n_estimators = trial.suggest_int("n_estimators", 1000, 8000)
    learning_rate = trial.suggest_float("learning_rate", 1e-2, 0.25, log=True)
    reg_lambda = trial.suggest_loguniform("reg_lambda", 1e-8, 100.0)
    reg_alpha = trial.suggest_loguniform("reg_alpha", 1e-8, 100.0)
    subsample = trial.suggest_float("subsample", 0.1, 1.0)
    colsample_bytree = trial.suggest_float("colsample_bytree", 0.1, 1.0)
    max_depth = trial.suggest_int("max_depth", 1, 7)




    final_predictions = []
    scores=[]
    for fold in range(5):
        xtrain =  df[df.kfold != fold].reset_index(drop=True)
        xvalid = df[df.kfold == fold].reset_index(drop=True)
        #xtest = df_test.copy()


        ytrain = xtrain.target
        yvalid = xvalid.target
        
        xtrain = xtrain[useful_features]
        xvalid = xvalid[useful_features]

    
        # standarization

        scaler = preprocessing.StandardScaler()
        xtrain[numerical_cols] = scaler.fit_transform(xtrain[numerical_cols])
        xvalid[numerical_cols] = scaler.transform(xvalid[numerical_cols])
        #xtest[numerical_cols] = scaler.transform(xtest[numerical_cols])

        # categorical features
        high_cardinality_cols = [col for col in object_cols if xtrain[col].nunique()>=9]
        low_cardinality_cols = [col for col in object_cols if xtrain[col].nunique()<9]
        
        
        # label encode columns with high cardinality 
        ordinal_encoder = preprocessing.OrdinalEncoder()
        xtrain[high_cardinality_cols] = ordinal_encoder.fit_transform(xtrain[high_cardinality_cols])
        xvalid[high_cardinality_cols] = ordinal_encoder.transform(xvalid[high_cardinality_cols])
        #xtest[high_cardinality_cols] = ordinal_encoder.transform(xtest[high_cardinality_cols])
        
        # One hot encode columns with low cardinality 
        OH_encoder = preprocessing.OneHotEncoder(handle_unknown='ignore', sparse=False)

        OH_cols_train = pd.DataFrame(OH_encoder.fit_transform(xtrain[low_cardinality_cols]))
        OH_cols_valid = pd.DataFrame(OH_encoder.transform(xvalid[low_cardinality_cols]))
        #OH_cols_test = pd.DataFrame(OH_encoder.transform(xtest[low_cardinality_cols]))

        # codificador one-hot elimina; ponerlo de nuevo 
        OH_cols_train.index = xtrain.index
        OH_cols_valid.index = xvalid.index
        #OH_cols_test.index = xtest.index

        # Eliminar columnas categóricas (se reemplazarán con codificación one-hot) 
        num_X_train = xtrain.drop(low_cardinality_cols, axis=1)
        num_X_valid = xvalid.drop(low_cardinality_cols, axis=1)
        #num_X_test= xtest.drop(low_cardinality_cols, axis=1)

        #  añadir columnas codificadas one-hot a variables numéricas 
        after_OH_xtrain = pd.concat([num_X_train, OH_cols_train], axis=1)
        after_OH_valid= pd.concat([num_X_valid, OH_cols_valid], axis=1)
        #after_OH_test= pd.concat([num_X_test, OH_cols_test], axis=1) 


        model = XGBRegressor(random_state=42, #fold, 
                            n_jobs=-1,
                            n_estimators= n_estimators,
                            tree_method='gpu_hist',
                            learning_rate= learning_rate,
                            subsample= subsample,
                            max_depth= max_depth,
                            colsample_bytree= colsample_bytree,
                            reg_alpha = reg_alpha,
                            eval_metric='rmse',
                            reg_lambda = reg_lambda,
                            gpu_id=0,predictor='gpu_predictor',
                            objective='reg:squarederror')
        
        
        model.fit(after_OH_xtrain, ytrain, early_stopping_rounds=300, eval_set=[(after_OH_valid,yvalid)], verbose=1000)
        preds_valid = model.predict(after_OH_valid)
        #test_preds = model.predict(after_OH_test)
        #final_predictions.append(test_preds)
        rmse = mean_squared_error(yvalid, preds_valid, squared=False)
        print(fold,rmse)
        scores.append(rmse)
        
    return np.mean(scores)

# %%
study = optuna.create_study(direction="minimize")
study.optimize(run, n_trials=100)
# Out:
# 1000]	validation_0-rmse:0.70907
# [2000]	validation_0-rmse:0.70808
# [2293]	validation_0-rmse:0.70814
# 1 0.7080701816331636
# [0]	validation_0-rmse:7.06439
# [1000]	validation_0-rmse:0.71123
# [2000]	validation_0-rmse:0.71028
# [2265]	validation_0-rmse:0.71036
# 2 0.7102682870444778
# [0]	validation_0-rmse:7.06708
# [1000]	validation_0-rmse:0.71038
# [2000]	validation_0-rmse:0.70944
# [2320]	validation_0-rmse:0.70947
# 3 0.7094082362921561
# [0]	validation_0-rmse:7.07580
# [1000]	validation_0-rmse:0.71014
# [2000]	validation_0-rmse:0.70918
# [2213]	validation_0-rmse:0.70926
# [I 2021-08-25 09:27:11,652] Trial 78 finished with value: 0.7086449465514028 and parameters: {'n_estimators': 5056, 'learning_rate': 0.09249401584717956, 'reg_lambda': 1.6412416410786828e-08, 'reg_alpha': 11.43640969390989, 'subsample': 0.8658397834396215, 'colsample_bytree': 0.2167330318570801, 'max_depth': 3}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7091669857012048
# [0]	validation_0-rmse:6.82383
# [1000]	validation_0-rmse:0.70730
# [1598]	validation_0-rmse:0.70713
# 0 0.7070400046791802
# [0]	validation_0-rmse:6.82021
# [1000]	validation_0-rmse:0.70868
# [1850]	validation_0-rmse:0.70840
# 1 0.7083018988125205
# [0]	validation_0-rmse:6.81794
# [1000]	validation_0-rmse:0.71087
# [1824]	validation_0-rmse:0.71083
# 2 0.7106508051626073
# [0]	validation_0-rmse:6.82067
# [1000]	validation_0-rmse:0.71015
# [1688]	validation_0-rmse:0.71037
# 3 0.7100927494584071
# [0]	validation_0-rmse:6.82605
# [528]	validation_0-rmse:0.72201
# [I 2021-08-25 09:28:19,334] Trial 79 finished with value: 0.7103624713409467 and parameters: {'n_estimators': 5107, 'learning_rate': 0.12447831072559527, 'reg_lambda': 1.8575252599529318e-08, 'reg_alpha': 0.49385162018546086, 'subsample': 0.8658120828225244, 'colsample_bytree': 0.16825382271167644, 'max_depth': 3}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7157268985920189
# [0]	validation_0-rmse:7.07624
# [1000]	validation_0-rmse:0.70861
# [2000]	validation_0-rmse:0.70720
# [3000]	validation_0-rmse:0.70700
# [3983]	validation_0-rmse:0.70691
# 0 0.7068995314709955
# [0]	validation_0-rmse:7.07256
# [1000]	validation_0-rmse:0.70981
# [2000]	validation_0-rmse:0.70862
# [2660]	validation_0-rmse:0.70856
# 1 0.7085109077541278
# [0]	validation_0-rmse:7.07030
# [1000]	validation_0-rmse:0.71211
# [2000]	validation_0-rmse:0.71098
# [2960]	validation_0-rmse:0.71094
# 2 0.7108965764834344
# [0]	validation_0-rmse:7.07301
# [1000]	validation_0-rmse:0.71123
# [2000]	validation_0-rmse:0.71003
# [2961]	validation_0-rmse:0.70988
# 3 0.709881361501307
# [0]	validation_0-rmse:7.07835
# [1000]	validation_0-rmse:0.71239
# [2000]	validation_0-rmse:0.71108
# [3000]	validation_0-rmse:0.71091
# [3322]	validation_0-rmse:0.71100
# [I 2021-08-25 09:30:43,483] Trial 80 finished with value: 0.7094112596347528 and parameters: {'n_estimators': 5308, 'learning_rate': 0.0917240306904327, 'reg_lambda': 1.0967651666221852e-08, 'reg_alpha': 66.89631041383346, 'subsample': 0.7951044575106052, 'colsample_bytree': 0.24970695212782407, 'max_depth': 3}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7108679209638994
# [0]	validation_0-rmse:6.98457
# [1000]	validation_0-rmse:0.70649
# [1642]	validation_0-rmse:0.70643
# 0 0.7062839093920066
# [0]	validation_0-rmse:6.98094
# [1000]	validation_0-rmse:0.70833
# [1554]	validation_0-rmse:0.70829
# 1 0.708140237745311
# [0]	validation_0-rmse:6.97866
# [1000]	validation_0-rmse:0.71045
# [1423]	validation_0-rmse:0.71048
# 2 0.7103669647385896
# [0]	validation_0-rmse:6.98135
# [1000]	validation_0-rmse:0.70988
# [1428]	validation_0-rmse:0.70994
# 3 0.709761164151664
# [0]	validation_0-rmse:6.98668
# [1000]	validation_0-rmse:0.70930
# [1553]	validation_0-rmse:0.70922
# [I 2021-08-25 09:32:03,267] Trial 81 finished with value: 0.7087401424889197 and parameters: {'n_estimators': 5483, 'learning_rate': 0.10361774398476273, 'reg_lambda': 2.4685199671507527e-08, 'reg_alpha': 13.495772640192435, 'subsample': 0.8843831701882333, 'colsample_bytree': 0.1539418784886632, 'max_depth': 4}. Best is trial 76 with value: 0.708572468839421.
# 4 0.709148436417027
# [0]	validation_0-rmse:6.99295
# [1000]	validation_0-rmse:0.70688
# [1138]	validation_0-rmse:0.70688
# 0 0.7067730642486016
# [0]	validation_0-rmse:6.98930
# [1000]	validation_0-rmse:0.70847
# [1123]	validation_0-rmse:0.70855
# 1 0.7083640966682889
# [0]	validation_0-rmse:6.98703
# [1000]	validation_0-rmse:0.71055
# [1075]	validation_0-rmse:0.71061
# 2 0.7105040492584297
# [0]	validation_0-rmse:6.98973
# [1000]	validation_0-rmse:0.71018
# [1126]	validation_0-rmse:0.71031
# 3 0.7100986270361925
# [0]	validation_0-rmse:6.99507
# [1000]	validation_0-rmse:0.70937
# [1155]	validation_0-rmse:0.70951
# [I 2021-08-25 09:33:13,996] Trial 82 finished with value: 0.7089898582697711 and parameters: {'n_estimators': 5555, 'learning_rate': 0.10253109356884317, 'reg_lambda': 2.2842444537012982e-08, 'reg_alpha': 10.918369515734305, 'subsample': 0.869172800307946, 'colsample_bytree': 0.13556103067393738, 'max_depth': 5}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7092094541373429
# [0]	validation_0-rmse:6.99816
# [1000]	validation_0-rmse:0.70725
# [1087]	validation_0-rmse:0.70727
# 0 0.7070381903082668
# [0]	validation_0-rmse:6.99469
# [1000]	validation_0-rmse:0.70849
# [1029]	validation_0-rmse:0.70853
# 1 0.7084058296919987
# [0]	validation_0-rmse:6.99235
# [922]	validation_0-rmse:0.71087
# 2 0.7108034903768505
# [0]	validation_0-rmse:6.99508
# [1000]	validation_0-rmse:0.71019
# [1164]	validation_0-rmse:0.71043
# 3 0.7100195057223819
# [0]	validation_0-rmse:7.00035
# [907]	validation_0-rmse:0.70978
# [I 2021-08-25 09:34:18,694] Trial 83 finished with value: 0.7091749687106843 and parameters: {'n_estimators': 5539, 'learning_rate': 0.10184537965287035, 'reg_lambda': 2.262188684642019e-08, 'reg_alpha': 6.528432881603893, 'subsample': 0.9872107223120998, 'colsample_bytree': 0.15712079046407357, 'max_depth': 5}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7096078274539235
# [0]	validation_0-rmse:6.92039
# [879]	validation_0-rmse:0.70785
# 0 0.707261663580865
# [0]	validation_0-rmse:6.91685
# [894]	validation_0-rmse:0.70921
# 1 0.7089663485174785
# [0]	validation_0-rmse:6.91446
# [932]	validation_0-rmse:0.71189
# 2 0.7113511093885853
# [0]	validation_0-rmse:6.91722
# [706]	validation_0-rmse:0.71158
# 3 0.7112531047262008
# [0]	validation_0-rmse:6.92304
# [450]	validation_0-rmse:0.74095
# [I 2021-08-25 09:35:09,037] Trial 84 finished with value: 0.7120655555718185 and parameters: {'n_estimators': 5508, 'learning_rate': 0.11194897316464926, 'reg_lambda': 1.5014017511923982e-08, 'reg_alpha': 1.1135154329391181e-08, 'subsample': 0.9904492216266072, 'colsample_bytree': 0.13912872712078134, 'max_depth': 5}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7214955516459634
# [0]	validation_0-rmse:6.63676
# [676]	validation_0-rmse:0.70893
# 0 0.7083525039334422
# [0]	validation_0-rmse:6.63322
# [777]	validation_0-rmse:0.71048
# 1 0.7093672155335619
# [0]	validation_0-rmse:6.63087
# [655]	validation_0-rmse:0.71286
# 2 0.7119229531364016
# [0]	validation_0-rmse:6.63361
# [711]	validation_0-rmse:0.71216
# 3 0.7111283906543764
# [0]	validation_0-rmse:6.64452
# [542]	validation_0-rmse:0.71889
# [I 2021-08-25 09:35:53,600] Trial 85 finished with value: 0.7104118514390085 and parameters: {'n_estimators': 5015, 'learning_rate': 0.1487672475553278, 'reg_lambda': 2.3869548129850915e-08, 'reg_alpha': 1.4034638063320615, 'subsample': 0.9418743439917403, 'colsample_bytree': 0.20739027804983923, 'max_depth': 5}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7112881939372604
# [0]	validation_0-rmse:7.00921
# [1000]	validation_0-rmse:0.70735
# [1066]	validation_0-rmse:0.70750
# 0 0.7069504429470779
# [0]	validation_0-rmse:7.00567
# [867]	validation_0-rmse:0.70896
# 1 0.7087599401777092
# [0]	validation_0-rmse:7.00339
# [788]	validation_0-rmse:0.71085
# 2 0.7106322088644677
# [0]	validation_0-rmse:7.00608
# [881]	validation_0-rmse:0.71054
# 3 0.7101319960306018
# [0]	validation_0-rmse:7.01137
# [948]	validation_0-rmse:0.71032
# [I 2021-08-25 09:37:03,527] Trial 86 finished with value: 0.7092686540752846 and parameters: {'n_estimators': 5852, 'learning_rate': 0.1004186954259889, 'reg_lambda': 2.5130209466728463e-08, 'reg_alpha': 12.125449472081264, 'subsample': 0.9739536536998238, 'colsample_bytree': 0.1371283216717764, 'max_depth': 6}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7098686823565666
# [0]	validation_0-rmse:6.87876
# [1000]	validation_0-rmse:0.70777
# [1008]	validation_0-rmse:0.70780
# 0 0.7073269450515761
# [0]	validation_0-rmse:6.87500
# [972]	validation_0-rmse:0.70935
# 1 0.7088909697375356
# [0]	validation_0-rmse:6.87277
# [823]	validation_0-rmse:0.71159
# 2 0.711335042802383
# [0]	validation_0-rmse:6.87550
# [782]	validation_0-rmse:0.71095
# 3 0.7107520418935217
# [0]	validation_0-rmse:6.88511
# [892]	validation_0-rmse:0.71801
# [I 2021-08-25 09:38:02,003] Trial 87 finished with value: 0.7111745104778924 and parameters: {'n_estimators': 5511, 'learning_rate': 0.11735675949872042, 'reg_lambda': 8.855981363871143e-08, 'reg_alpha': 15.191766435683332, 'subsample': 0.8176062075918737, 'colsample_bytree': 0.2448518812358083, 'max_depth': 5}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7175675529044458
# [0]	validation_0-rmse:7.12086
# [1000]	validation_0-rmse:0.70728
# [1518]	validation_0-rmse:0.70711
# 0 0.7070983737354766
# [0]	validation_0-rmse:7.11729
# [1000]	validation_0-rmse:0.70855
# [1475]	validation_0-rmse:0.70845
# 1 0.7083637008798265
# [0]	validation_0-rmse:7.11505
# [1000]	validation_0-rmse:0.71075
# [1485]	validation_0-rmse:0.71073
# 2 0.7106102982495358
# [0]	validation_0-rmse:7.11775
# [1000]	validation_0-rmse:0.71020
# [1449]	validation_0-rmse:0.71025
# 3 0.7100823011040914
# [0]	validation_0-rmse:7.12307
# [715]	validation_0-rmse:0.71681
# [I 2021-08-25 09:39:10,692] Trial 88 finished with value: 0.7096213957997232 and parameters: {'n_estimators': 5206, 'learning_rate': 0.08591724593541128, 'reg_lambda': 0.17577567448177997, 'reg_alpha': 2.403596232864778, 'subsample': 0.8428209327338754, 'colsample_bytree': 0.18413784089754856, 'max_depth': 4}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7119523050296858
# [0]	validation_0-rmse:6.30452
# [579]	validation_0-rmse:0.70949
# 0 0.7082755896011906
# [0]	validation_0-rmse:6.30086
# [682]	validation_0-rmse:0.71122
# 1 0.7097435652378205
# [0]	validation_0-rmse:6.29855
# [562]	validation_0-rmse:0.71303
# 2 0.7122420682552055
# [0]	validation_0-rmse:6.30133
# [529]	validation_0-rmse:0.71294
# 3 0.7120361900978796
# [0]	validation_0-rmse:6.31434
# [623]	validation_0-rmse:0.72550
# [I 2021-08-25 09:39:51,506] Trial 89 finished with value: 0.7127517285668603 and parameters: {'n_estimators': 4861, 'learning_rate': 0.19193721306522765, 'reg_lambda': 1.4398707026187685e-07, 'reg_alpha': 4.893469620591564, 'subsample': 0.887431304386229, 'colsample_bytree': 0.28096369726512926, 'max_depth': 5}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7214612296422055
# [0]	validation_0-rmse:7.03935
# [1000]	validation_0-rmse:0.70749
# [1271]	validation_0-rmse:0.70757
# 0 0.7074727035707361
# [0]	validation_0-rmse:7.03587
# [1000]	validation_0-rmse:0.70921
# [1378]	validation_0-rmse:0.70922
# 1 0.709105426694464
# [0]	validation_0-rmse:7.03353
# [1000]	validation_0-rmse:0.71120
# [1270]	validation_0-rmse:0.71128
# 2 0.7111548687115526
# [0]	validation_0-rmse:7.03628
# [1000]	validation_0-rmse:0.71122
# [1201]	validation_0-rmse:0.71120
# 3 0.7107700951878022
# [0]	validation_0-rmse:7.04511
# [636]	validation_0-rmse:0.72823
# [I 2021-08-25 09:40:53,464] Trial 90 finished with value: 0.7109243425887916 and parameters: {'n_estimators': 6151, 'learning_rate': 0.09649486944836833, 'reg_lambda': 0.0018941479256701197, 'reg_alpha': 0.002063343979903036, 'subsample': 0.9987819535013869, 'colsample_bytree': 0.23278894265292657, 'max_depth': 4}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7161186187794026
# [0]	validation_0-rmse:7.18747
# [1000]	validation_0-rmse:0.70696
# [1169]	validation_0-rmse:0.70713
# 0 0.7068159735756874
# [0]	validation_0-rmse:7.18392
# [1000]	validation_0-rmse:0.70870
# [1134]	validation_0-rmse:0.70883
# 1 0.7085201851344011
# [0]	validation_0-rmse:7.18164
# [997]	validation_0-rmse:0.71072
# 2 0.7106000246039974
# [0]	validation_0-rmse:7.18429
# [1000]	validation_0-rmse:0.71030
# [1124]	validation_0-rmse:0.71049
# 3 0.7101015981037638
# [0]	validation_0-rmse:7.18957
# [991]	validation_0-rmse:0.71011
# [I 2021-08-25 09:42:15,057] Trial 91 finished with value: 0.7091926274662221 and parameters: {'n_estimators': 5770, 'learning_rate': 0.07728305103281895, 'reg_lambda': 5.6356590378755396e-08, 'reg_alpha': 9.574292932494883, 'subsample': 0.9514868616122354, 'colsample_bytree': 0.1498212330898874, 'max_depth': 6}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7099253559132607
# [0]	validation_0-rmse:7.17437
# [1000]	validation_0-rmse:0.70661
# [1607]	validation_0-rmse:0.70654
# 0 0.706486075455247
# [0]	validation_0-rmse:7.17085
# [1000]	validation_0-rmse:0.70830
# [1620]	validation_0-rmse:0.70822
# 1 0.7081372712279225
# [0]	validation_0-rmse:7.16855
# [1000]	validation_0-rmse:0.71035
# [1647]	validation_0-rmse:0.71041
# 2 0.7102248979471936
# [0]	validation_0-rmse:7.17120
# [1000]	validation_0-rmse:0.70976
# [1585]	validation_0-rmse:0.70973
# 3 0.7096444964171267
# [0]	validation_0-rmse:7.17649
# [1000]	validation_0-rmse:0.70943
# [1711]	validation_0-rmse:0.70943
# [I 2021-08-25 09:44:11,286] Trial 92 finished with value: 0.7087448194091589 and parameters: {'n_estimators': 5422, 'learning_rate': 0.07898463585993755, 'reg_lambda': 5.71095627306973e-08, 'reg_alpha': 33.914005899155704, 'subsample': 0.9536524655576382, 'colsample_bytree': 0.10324143709160677, 'max_depth': 6}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7092313559983043
# [0]	validation_0-rmse:6.97833
# [1000]	validation_0-rmse:0.70715
# [1031]	validation_0-rmse:0.70719
# 0 0.7068142991693785
# [0]	validation_0-rmse:6.97474
# [1000]	validation_0-rmse:0.70901
# [1082]	validation_0-rmse:0.70914
# 1 0.708655510129072
# [0]	validation_0-rmse:6.97247
# [943]	validation_0-rmse:0.71107
# 2 0.7107024199740759
# [0]	validation_0-rmse:6.97512
# [972]	validation_0-rmse:0.71047
# 3 0.710246050640391
# [0]	validation_0-rmse:6.98044
# [1000]	validation_0-rmse:0.70977
# [1024]	validation_0-rmse:0.70986
# [I 2021-08-25 09:45:41,979] Trial 93 finished with value: 0.7091676647795231 and parameters: {'n_estimators': 5426, 'learning_rate': 0.1044295817775835, 'reg_lambda': 1.683764322006591e-08, 'reg_alpha': 38.824416607850395, 'subsample': 0.9043376160537226, 'colsample_bytree': 0.12140228677166304, 'max_depth': 7}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7094200439846975
# [0]	validation_0-rmse:6.73628
# [860]	validation_0-rmse:0.70730
# 0 0.7069758759322485
# [0]	validation_0-rmse:6.73268
# [861]	validation_0-rmse:0.70908
# 1 0.7086650713545763
# [0]	validation_0-rmse:6.73039
# [758]	validation_0-rmse:0.71127
# 2 0.7106755103311385
# [0]	validation_0-rmse:6.73304
# [804]	validation_0-rmse:0.71052
# 3 0.7100699646669557
# [0]	validation_0-rmse:6.73842
# [944]	validation_0-rmse:0.71046
# [I 2021-08-25 09:46:58,172] Trial 94 finished with value: 0.7092335808417946 and parameters: {'n_estimators': 5377, 'learning_rate': 0.13585756376917196, 'reg_lambda': 1.070769270938705e-08, 'reg_alpha': 34.5784452802807, 'subsample': 0.8978452354395772, 'colsample_bytree': 0.11215218383009178, 'max_depth': 7}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7097814819240537
# [0]	validation_0-rmse:7.12767
# [1000]	validation_0-rmse:0.70717
# [1741]	validation_0-rmse:0.70706
# 0 0.7069853749270061
# [0]	validation_0-rmse:7.12408
# [1000]	validation_0-rmse:0.70873
# [1627]	validation_0-rmse:0.70867
# 1 0.7085529766939856
# [0]	validation_0-rmse:7.12180
# [1000]	validation_0-rmse:0.71086
# [1620]	validation_0-rmse:0.71086
# 2 0.7107594220923912
# [0]	validation_0-rmse:7.12448
# [1000]	validation_0-rmse:0.71031
# [1628]	validation_0-rmse:0.71018
# 3 0.7101245009599976
# [0]	validation_0-rmse:7.12978
# [1000]	validation_0-rmse:0.70993
# [1655]	validation_0-rmse:0.70988
# [I 2021-08-25 09:49:09,721] Trial 95 finished with value: 0.7092529731377141 and parameters: {'n_estimators': 5008, 'learning_rate': 0.08504710469645832, 'reg_lambda': 3.666856981129726e-08, 'reg_alpha': 80.91634941678647, 'subsample': 0.8707909013251495, 'colsample_bytree': 0.126991731010609, 'max_depth': 7}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7098425910151903
# [0]	validation_0-rmse:7.05901
# [651]	validation_0-rmse:0.70929
# 0 0.7084304971320867
# [0]	validation_0-rmse:7.05550
# [743]	validation_0-rmse:0.71070
# 1 0.710066939981798
# [0]	validation_0-rmse:7.05319
# [787]	validation_0-rmse:0.71327
# 2 0.7123349350658871
# [0]	validation_0-rmse:7.05598
# [708]	validation_0-rmse:0.71264
# 3 0.7116952026638539
# [0]	validation_0-rmse:7.06485
# [451]	validation_0-rmse:0.72817
# [I 2021-08-25 09:50:02,603] Trial 96 finished with value: 0.712056640564976 and parameters: {'n_estimators': 4740, 'learning_rate': 0.0939412967827351, 'reg_lambda': 9.060820351884451e-08, 'reg_alpha': 0.011026542048203237, 'subsample': 0.9640952827934993, 'colsample_bytree': 0.22124373892498173, 'max_depth': 6}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7177556279812543
# [0]	validation_0-rmse:7.20442
# [1000]	validation_0-rmse:0.70656
# [1602]	validation_0-rmse:0.70651
# 0 0.7064947222066074
# [0]	validation_0-rmse:7.20087
# [1000]	validation_0-rmse:0.70829
# [1452]	validation_0-rmse:0.70829
# 1 0.7081842207644206
# [0]	validation_0-rmse:7.19861
# [1000]	validation_0-rmse:0.71019
# [1362]	validation_0-rmse:0.71016
# 2 0.7101211801858899
# [0]	validation_0-rmse:7.20128
# [1000]	validation_0-rmse:0.70988
# [1766]	validation_0-rmse:0.70986
# 3 0.7097415171933638
# [0]	validation_0-rmse:7.20657
# [1000]	validation_0-rmse:0.70991
# [1610]	validation_0-rmse:0.70997
# [I 2021-08-25 09:52:07,903] Trial 97 finished with value: 0.708867834435673 and parameters: {'n_estimators': 4597, 'learning_rate': 0.07508174928863452, 'reg_lambda': 1.552835996979788e-07, 'reg_alpha': 45.38539227250981, 'subsample': 0.851898871588423, 'colsample_bytree': 0.10211854592234948, 'max_depth': 7}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7097975318280837
# [0]	validation_0-rmse:7.26281
# [1000]	validation_0-rmse:0.70775
# [1366]	validation_0-rmse:0.70771
# 0 0.70768257706117
# [0]	validation_0-rmse:7.25887
# [1000]	validation_0-rmse:0.70925
# [1703]	validation_0-rmse:0.70915
# 1 0.709007041596872
# [0]	validation_0-rmse:7.25664
# [1000]	validation_0-rmse:0.71174
# [1335]	validation_0-rmse:0.71180
# 2 0.7116957896878042
# [0]	validation_0-rmse:7.25927
# [1000]	validation_0-rmse:0.71125
# [1356]	validation_0-rmse:0.71132
# 3 0.7111129501795651
# [0]	validation_0-rmse:7.26454
# [1000]	validation_0-rmse:0.71090
# [1741]	validation_0-rmse:0.71123
# [I 2021-08-25 09:53:40,239] Trial 98 finished with value: 0.7100526420573845 and parameters: {'n_estimators': 4630, 'learning_rate': 0.06753158830582807, 'reg_lambda': 1.8600308640656723e-07, 'reg_alpha': 16.936121748738124, 'subsample': 0.214243743086244, 'colsample_bytree': 0.10419901314510294, 'max_depth': 6}. Best is trial 76 with value: 0.708572468839421.
# 4 0.710764851761511
# [0]	validation_0-rmse:7.17843
# [1000]	validation_0-rmse:0.70709
# [2000]	validation_0-rmse:0.70635
# [2301]	validation_0-rmse:0.70653
# 0 0.706347388213253
# [0]	validation_0-rmse:7.17473
# [1000]	validation_0-rmse:0.70867
# [1805]	validation_0-rmse:0.70820
# 1 0.7081755122779149
# [0]	validation_0-rmse:7.17248
# [1000]	validation_0-rmse:0.71090
# [1794]	validation_0-rmse:0.71055
# 2 0.7105058250966801
# [0]	validation_0-rmse:7.17521
# [1000]	validation_0-rmse:0.71033
# [2000]	validation_0-rmse:0.70982
# [2337]	validation_0-rmse:0.70992
# 3 0.709791429604165
# [0]	validation_0-rmse:7.18049
# [1000]	validation_0-rmse:0.71015
# [2000]	validation_0-rmse:0.70975
# [2024]	validation_0-rmse:0.70974
# [I 2021-08-25 09:55:26,486] Trial 99 finished with value: 0.7088863730961525 and parameters: {'n_estimators': 4932, 'learning_rate': 0.07846207536205771, 'reg_lambda': 6.413596681256098e-07, 'reg_alpha': 31.086571653815817, 'subsample': 0.7612539746787066, 'colsample_bytree': 0.18212972172220693, 'max_depth': 4}. Best is trial 76 with value: 0.708572468839421.
# 4 0.7096117102887503

# %% [markdown]
# 0.7289161215950625  ordinal + stand   <br>
# 0.7359939686055645  ordinal + normalizer <br>
# 0.7339300282189536  ordinal + standard + normalizer <br>
# 0.7359933943841589  ordinal + normalizer +standard   <br>
# 0.7288775872910201  ohe + stand   <br>
# 0.7359376887794242   ohe + normalizer   <br>
# 0.7289403434752502 (ohe+ 3 ordinal) + stand   <br>
# 0.7291070689887855  poly3 (T,F) (ohe+ 1 ordinal) + stand   <br>
# 0.72914235959686  poly3 (F,F) (ohe+ 1 ordinal) + stand   <br>
# 0.728907008813998  poly2 (F,F) (ohe+ 1 ordinal) + stand   <br>
# 0.7289321289479873   poly2 (F,T) (ohe+ 1 ordinal) + stand   <br>
# 0.7289501787229472   poly2 (T,T) (ohe+ 1 ordinal) + stand   <br>
# 0.7289416327232601   poly2 (T,F) (ohe+ 1 ordinal) + stand   <br>
#
# 0.7288644838881868  (ohe+ 1 ordinal) + stand   <br>
# -0.7189543356528036   T_outliers+ (ohe+ 1 ordinal) + stand <br>
# 0.7205793549092518    T_encoding + T_outliers+ (ohe+ 1 ordinal) + stand <br>

# %%
study.best_params
# Out:
# {'n_estimators': 5234,
#  'learning_rate': 0.08970028112557221,
#  'reg_lambda': 9.309499343828611e-07,
#  'reg_alpha': 23.955318691526553,
#  'subsample': 0.9487438254800091,
#  'colsample_bytree': 0.3685425845467418,
#  'max_depth': 2}

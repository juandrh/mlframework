# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import make_scorer
from xgboost import XGBRegressor, DMatrix

import matplotlib.pyplot as plt
# %matplotlib inline            
import seaborn as sns

from time import time
import pprint
import joblib
from functools import partial

# Suppressing warnings because of skopt verbosity
import warnings
warnings.filterwarnings("ignore")

# Skopt functions
from skopt import BayesSearchCV
from skopt.callbacks import DeadlineStopper, DeltaYStopper
from skopt.space import Real, Categorical, Integer

# Model selection
from sklearn.model_selection import KFold

import optuna


from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
df = pd.read_csv("../input/train_folds.csv")
df_test = pd.read_csv("../input/test.csv")
sample_submission = pd.read_csv("../input/sample_submission.csv")

df = df.drop(df[df['target'].lt(6)].index)
print(df.shape)

useful_features = [c for c in df.columns if c not in ("id", "target", "kfold")]
object_cols = [col for col in useful_features if 'cat' in col]
numerical_cols = [col for col in useful_features if 'cont' in col]
df_test = df_test[useful_features]

# target encoding
for col in object_cols:
    temp_df = []
    temp_test_feat = None
    for fold in range(5):
        xtrain =  df[df.kfold != fold].reset_index(drop=True)
        xvalid = df[df.kfold == fold].reset_index(drop=True)
        feat = xtrain.groupby(col)["target"].agg("mean")
        feat = feat.to_dict()
        xvalid.loc[:, f"tar_enc_{col}"] = xvalid[col].map(feat)
        temp_df.append(xvalid)
        if temp_test_feat is None:
            temp_test_feat = df_test[col].map(feat)
        else:
            temp_test_feat += df_test[col].map(feat)
    
    temp_test_feat /= 5
    df_test.loc[:, f"tar_enc_{col}"] = temp_test_feat
    df = pd.concat(temp_df)

useful_features = [c for c in df.columns if c not in ("id", "target", "kfold")]
object_cols = [col for col in useful_features if col.startswith("cat")]
df_test = df_test[useful_features]

# Processing categoricals with SVD encoding
X_seq = df[object_cols].apply(lambda x: " ".join(list([str(y) + str(i) for i, y in enumerate(x)])), axis=1)
X_test_seq = df_test[object_cols].apply(lambda x: " ".join(list([str(y) + str(i) for i, y in enumerate(x)])), axis=1)


latent_dims = 24

svd_feats = ['svd_'+str(l) for l in range(latent_dims)]
vectorizer = TfidfVectorizer()

dim_reductio = TruncatedSVD(n_components=24, random_state=0)
df[svd_feats] =  dim_reductio.fit_transform(vectorizer.fit_transform(X_seq))
df_test[svd_feats] = dim_reductio.transform(vectorizer.transform(X_test_seq))


    
# Processing categoricals with frequency encoding
object_cols = [item for item in df.columns if 'cat' in item]

for cat in object_cols:
    counts = dict(df[cat].value_counts() / len(df))
    df[cat+'_freq'] = df[cat].replace(counts)
    df_test[cat+'_freq'] = df_test[cat].replace(counts)

frequencies = [cat+'_freq' for cat in object_cols]


useful_features = [c for c in df.columns if c not in ("id", "target", "kfold")]
# Out:
# (299628, 27)

# %%
def run(trial):

    n_estimators = trial.suggest_int("n_estimators", 1000, 8000)
    learning_rate = trial.suggest_float("learning_rate", 1e-2, 0.25, log=True)
    reg_lambda = trial.suggest_loguniform("reg_lambda", 1e-8, 100.0)
    reg_alpha = trial.suggest_loguniform("reg_alpha", 1e-8, 100.0)
    subsample = trial.suggest_float("subsample", 0.1, 1.0)
    colsample_bytree = trial.suggest_float("colsample_bytree", 0.1, 1.0)
    max_depth = trial.suggest_int("max_depth", 1, 7)




    final_predictions = []
    scores=[]
    for fold in range(5):
        xtrain =  df[df.kfold != fold].reset_index(drop=True)
        xvalid = df[df.kfold == fold].reset_index(drop=True)
        #xtest = df_test.copy()


        ytrain = xtrain.target
        yvalid = xvalid.target
        
        xtrain = xtrain[useful_features]
        xvalid = xvalid[useful_features]

    
        # standarization

        scaler = preprocessing.StandardScaler()
        xtrain[numerical_cols] = scaler.fit_transform(xtrain[numerical_cols])
        xvalid[numerical_cols] = scaler.transform(xvalid[numerical_cols])
        #xtest[numerical_cols] = scaler.transform(xtest[numerical_cols])

        
 
        # label encode columns 
        ordinal_encoder = preprocessing.OrdinalEncoder()
        xtrain[object_cols] = ordinal_encoder.fit_transform(xtrain[object_cols])
        xvalid[object_cols] = ordinal_encoder.fit_transform(xvalid[object_cols])
        #xtest[object_cols] = ordinal_encoder.fit_transform(xtest[object_cols])

        model = XGBRegressor(random_state=42, #fold, 
                            n_jobs=-1,
                            n_estimators= n_estimators,
                            tree_method='gpu_hist',
                            learning_rate= learning_rate,
                            subsample= subsample,
                            max_depth= max_depth,
                            colsample_bytree= colsample_bytree,
                            reg_alpha = reg_alpha,
                            eval_metric='rmse',
                            reg_lambda = reg_lambda,
                            gpu_id=0,predictor='gpu_predictor',
                            objective='reg:squarederror')
        
        
        model.fit(xtrain, ytrain, early_stopping_rounds=300, eval_set=[(xvalid,yvalid)], verbose=1000)
        preds_valid = model.predict(xvalid)
        #test_preds = model.predict(after_OH_test)
        #final_predictions.append(test_preds)
        rmse = mean_squared_error(yvalid, preds_valid, squared=False)
        print(fold,rmse)
        scores.append(rmse)
        
    return np.mean(scores)

# %%
study = optuna.create_study(direction="minimize")
study.optimize(run, n_trials=30)
# Out:
# 43166167, 'reg_lambda': 9.958442360634781e-05, 'reg_alpha': 1.3585634532238833e-05, 'subsample': 0.8239696252566668, 'colsample_bytree': 0.6826662271904085, 'max_depth': 5}. Best is trial 5 with value: 0.7144889134825391.
# 4 0.7158508040373192
# [0]	validation_0-rmse:7.67363
# [1000]	validation_0-rmse:0.71653
# [2000]	validation_0-rmse:0.71376
# [2518]	validation_0-rmse:0.71905
# 0 0.7133948836491598
# [0]	validation_0-rmse:7.67013
# [1000]	validation_0-rmse:0.71835
# [1811]	validation_0-rmse:0.71676
# 1 0.7159879792672085
# [0]	validation_0-rmse:7.66782
# [1000]	validation_0-rmse:0.72143
# [1337]	validation_0-rmse:0.72225
# 2 0.7212496285758292
# [0]	validation_0-rmse:7.67048
# [1000]	validation_0-rmse:0.72019
# [1704]	validation_0-rmse:0.71927
# 3 0.7186024119176905
# [0]	validation_0-rmse:7.67568
# [1000]	validation_0-rmse:0.71964
# [1993]	validation_0-rmse:0.71797
# [I 2021-08-25 13:18:51,740] Trial 9 finished with value: 0.7172776059001358 and parameters: {'n_estimators': 2660, 'learning_rate': 0.014262015679495926, 'reg_lambda': 1.73748454818143e-08, 'reg_alpha': 6.421526320037955e-05, 'subsample': 0.4007692812519208, 'colsample_bytree': 0.18780120865168698, 'max_depth': 3}. Best is trial 5 with value: 0.7144889134825391.
# 4 0.7171531260907913
# [0]	validation_0-rmse:7.55346
# [1000]	validation_0-rmse:0.71517
# [1567]	validation_0-rmse:0.71302
# 0 0.7130225024828137
# [0]	validation_0-rmse:7.55002
# [1000]	validation_0-rmse:0.71786
# [1567]	validation_0-rmse:0.71578
# 1 0.7157761818128855
# [0]	validation_0-rmse:7.54772
# [1000]	validation_0-rmse:0.72222
# [1567]	validation_0-rmse:0.72033
# 2 0.7203247316521088
# [0]	validation_0-rmse:7.55036
# [1000]	validation_0-rmse:0.71898
# [1567]	validation_0-rmse:0.71704
# 3 0.7170385454986831
# [0]	validation_0-rmse:7.55555
# [1000]	validation_0-rmse:0.71956
# [1567]	validation_0-rmse:0.71741
# [I 2021-08-25 13:20:47,100] Trial 10 finished with value: 0.7167133998833825 and parameters: {'n_estimators': 1568, 'learning_rate': 0.029792880541214668, 'reg_lambda': 0.00018663733393066415, 'reg_alpha': 35.822794609365175, 'subsample': 0.9985266845122689, 'colsample_bytree': 0.9539603024045301, 'max_depth': 4}. Best is trial 5 with value: 0.7144889134825391.
# 4 0.717405037970421
# [0]	validation_0-rmse:7.53654
# [686]	validation_0-rmse:0.72442
# 0 0.7117442023050796
# [0]	validation_0-rmse:7.53319
# [983]	validation_0-rmse:0.71753
# 1 0.713719184910594
# [0]	validation_0-rmse:7.53160
# [899]	validation_0-rmse:0.71909
# 2 0.7152237629365356
# [0]	validation_0-rmse:7.53343
# [892]	validation_0-rmse:0.71859
# 3 0.7156481099495358
# [0]	validation_0-rmse:7.53870
# [768]	validation_0-rmse:0.72134
# [I 2021-08-25 13:22:33,305] Trial 11 finished with value: 0.7144426009030374 and parameters: {'n_estimators': 1152, 'learning_rate': 0.03208971995086959, 'reg_lambda': 1.1938468194595565e-06, 'reg_alpha': 0.03400151629012158, 'subsample': 0.7770169141047018, 'colsample_bytree': 0.4513386220451478, 'max_depth': 7}. Best is trial 11 with value: 0.7144426009030374.
# 4 0.7158777444134419
# [0]	validation_0-rmse:7.53381
# [806]	validation_0-rmse:0.71628
# 0 0.7124484907225088
# [0]	validation_0-rmse:7.53071
# [901]	validation_0-rmse:0.71570
# 1 0.7137774822893317
# [0]	validation_0-rmse:7.52823
# [881]	validation_0-rmse:0.72214
# 2 0.7161872115285448
# [0]	validation_0-rmse:7.53116
# [824]	validation_0-rmse:0.72105
# 3 0.7153442146346222
# [0]	validation_0-rmse:7.53614
# [824]	validation_0-rmse:0.71998
# [I 2021-08-25 13:24:00,850] Trial 12 finished with value: 0.7145817653492912 and parameters: {'n_estimators': 1129, 'learning_rate': 0.03241063811603975, 'reg_lambda': 1.407023935812783e-06, 'reg_alpha': 0.05365731606847457, 'subsample': 0.8389220829600539, 'colsample_bytree': 0.42876017264984134, 'max_depth': 6}. Best is trial 11 with value: 0.7144426009030374.
# 4 0.7151514275714492
# [0]	validation_0-rmse:7.48841
# [697]	validation_0-rmse:0.73444
# 0 0.7122630644715348
# [0]	validation_0-rmse:7.48516
# [622]	validation_0-rmse:0.72069
# 1 0.7151918722741499
# [0]	validation_0-rmse:7.48281
# [590]	validation_0-rmse:0.71851
# 2 0.7183844878939891
# [0]	validation_0-rmse:7.48545
# [560]	validation_0-rmse:0.72171
# 3 0.7176449177335252
# [0]	validation_0-rmse:7.49076
# [674]	validation_0-rmse:0.72123
# [I 2021-08-25 13:25:32,350] Trial 13 finished with value: 0.7157959111538975 and parameters: {'n_estimators': 2385, 'learning_rate': 0.03830244412550591, 'reg_lambda': 2.0316238379118297e-05, 'reg_alpha': 0.05789402269779885, 'subsample': 0.7994508159907212, 'colsample_bytree': 0.8128791086109427, 'max_depth': 7}. Best is trial 11 with value: 0.7144426009030374.
# 4 0.7154952133962886
# [0]	validation_0-rmse:7.30335
# [1000]	validation_0-rmse:0.70985
# [1391]	validation_0-rmse:0.71014
# 0 0.7097505379849277
# [0]	validation_0-rmse:7.29985
# [1000]	validation_0-rmse:0.71167
# [1303]	validation_0-rmse:0.71198
# 1 0.7116632267134603
# [0]	validation_0-rmse:7.29744
# [1000]	validation_0-rmse:0.71367
# [1230]	validation_0-rmse:0.71381
# 2 0.7135969191632091
# [0]	validation_0-rmse:7.30021
# [1000]	validation_0-rmse:0.71379
# [1273]	validation_0-rmse:0.71402
# 3 0.7137457125333655
# [0]	validation_0-rmse:7.30552
# [1000]	validation_0-rmse:0.71214
# [1361]	validation_0-rmse:0.71240
# [I 2021-08-25 13:27:12,008] Trial 14 finished with value: 0.7121483872237118 and parameters: {'n_estimators': 3603, 'learning_rate': 0.06239293144776865, 'reg_lambda': 1.3037101588758642e-07, 'reg_alpha': 7.504140376535213, 'subsample': 0.705162726494265, 'colsample_bytree': 0.45293039229321724, 'max_depth': 5}. Best is trial 14 with value: 0.7121483872237118.
# 4 0.7119855397235962
# [0]	validation_0-rmse:7.61454
# [1000]	validation_0-rmse:0.71795
# [2000]	validation_0-rmse:0.71464
# [3000]	validation_0-rmse:0.71353
# [3160]	validation_0-rmse:0.71347
# 0 0.7134499128136589
# [0]	validation_0-rmse:7.61108
# [1000]	validation_0-rmse:0.71518
# [2000]	validation_0-rmse:0.71220
# [3000]	validation_0-rmse:0.71130
# [3160]	validation_0-rmse:0.71122
# 1 0.7112180938811626
# [0]	validation_0-rmse:7.60879
# [1000]	validation_0-rmse:0.72241
# [2000]	validation_0-rmse:0.71927
# [3000]	validation_0-rmse:0.71827
# [3160]	validation_0-rmse:0.71817
# 2 0.7181722871871534
# [0]	validation_0-rmse:7.61142
# [1000]	validation_0-rmse:0.71599
# [2000]	validation_0-rmse:0.71308
# [3000]	validation_0-rmse:0.71240
# [3160]	validation_0-rmse:0.71237
# 3 0.7123602453676467
# [0]	validation_0-rmse:7.61661
# [1000]	validation_0-rmse:0.71688
# [2000]	validation_0-rmse:0.71372
# [3000]	validation_0-rmse:0.71273
# [3160]	validation_0-rmse:0.71268
# [I 2021-08-25 13:31:23,377] Trial 15 finished with value: 0.7135751894469136 and parameters: {'n_estimators': 3161, 'learning_rate': 0.02187099467705971, 'reg_lambda': 0.002511453343369922, 'reg_alpha': 31.29074709376275, 'subsample': 0.9495760226835699, 'colsample_bytree': 0.4724852183229949, 'max_depth': 5}. Best is trial 14 with value: 0.7121483872237118.
# 4 0.7126754079849461
# [0]	validation_0-rmse:7.62265
# [1000]	validation_0-rmse:0.71572
# [2000]	validation_0-rmse:0.71235
# [3000]	validation_0-rmse:0.71109
# [3559]	validation_0-rmse:0.71074
# 0 0.7107409518566822
# [0]	validation_0-rmse:7.61920
# [1000]	validation_0-rmse:0.71613
# [2000]	validation_0-rmse:0.71288
# [3000]	validation_0-rmse:0.71190
# [3559]	validation_0-rmse:0.71160
# 1 0.7115981724229337
# [0]	validation_0-rmse:7.61690
# [1000]	validation_0-rmse:0.71876
# [2000]	validation_0-rmse:0.71554
# [3000]	validation_0-rmse:0.71450
# [3559]	validation_0-rmse:0.71422
# 2 0.7142205378849269
# [0]	validation_0-rmse:7.61955
# [1000]	validation_0-rmse:0.71957
# [2000]	validation_0-rmse:0.71649
# [3000]	validation_0-rmse:0.71534
# [3559]	validation_0-rmse:0.71503
# 3 0.7150269748820192
# [0]	validation_0-rmse:7.62473
# [1000]	validation_0-rmse:0.71834
# [2000]	validation_0-rmse:0.71473
# [3000]	validation_0-rmse:0.71357
# [3559]	validation_0-rmse:0.71326
# [I 2021-08-25 13:36:19,231] Trial 16 finished with value: 0.7129699462826862 and parameters: {'n_estimators': 3560, 'learning_rate': 0.020820299390678466, 'reg_lambda': 0.004566922582267104, 'reg_alpha': 85.56079631388415, 'subsample': 0.9964391696403946, 'colsample_bytree': 0.45267529630869635, 'max_depth': 5}. Best is trial 14 with value: 0.7121483872237118.
# 4 0.7132630943668692
# [0]	validation_0-rmse:6.97393
# [1000]	validation_0-rmse:0.71718
# [2000]	validation_0-rmse:0.71493
# [3000]	validation_0-rmse:0.71393
# [3869]	validation_0-rmse:0.71315
# 0 0.7131448841289495
# [0]	validation_0-rmse:6.97022
# [1000]	validation_0-rmse:0.71871
# [2000]	validation_0-rmse:0.71652
# [3000]	validation_0-rmse:0.71534
# [3843]	validation_0-rmse:0.71496
# 1 0.7149250923559118
# [0]	validation_0-rmse:6.96778
# [1000]	validation_0-rmse:0.72070
# [1936]	validation_0-rmse:0.71958
# 2 0.7190430322193121
# [0]	validation_0-rmse:6.97059
# [1000]	validation_0-rmse:0.71961
# [2000]	validation_0-rmse:0.71722
# [3000]	validation_0-rmse:0.71601
# [3346]	validation_0-rmse:0.71676
# 3 0.7159620308376605
# [0]	validation_0-rmse:6.97596
# [1000]	validation_0-rmse:0.71971
# [2000]	validation_0-rmse:0.71726
# [3000]	validation_0-rmse:0.71581
# [3869]	validation_0-rmse:0.71551
# [I 2021-08-25 13:38:26,698] Trial 17 finished with value: 0.7156079128463627 and parameters: {'n_estimators': 3870, 'learning_rate': 0.10500365629055038, 'reg_lambda': 0.20815387326980073, 'reg_alpha': 2.852783264223469, 'subsample': 0.6785290813947829, 'colsample_bytree': 0.35612631120542937, 'max_depth': 1}. Best is trial 14 with value: 0.7121483872237118.
# 4 0.7149645246899794
# [0]	validation_0-rmse:7.61775
# [1000]	validation_0-rmse:0.71209
# [2000]	validation_0-rmse:0.70980
# [3000]	validation_0-rmse:0.70943
# [3369]	validation_0-rmse:0.70949
# 0 0.7093938260781506
# [0]	validation_0-rmse:7.61430
# [1000]	validation_0-rmse:0.71307
# [2000]	validation_0-rmse:0.71089
# [3000]	validation_0-rmse:0.71075
# [3018]	validation_0-rmse:0.71075
# 1 0.7105665214334248
# [0]	validation_0-rmse:7.61198
# [1000]	validation_0-rmse:0.71570
# [2000]	validation_0-rmse:0.71362
# [2206]	validation_0-rmse:0.71368
# 2 0.7133889287874218
# [0]	validation_0-rmse:7.61463
# [1000]	validation_0-rmse:0.71505
# [2000]	validation_0-rmse:0.71254
# [3000]	validation_0-rmse:0.71213
# [3182]	validation_0-rmse:0.71218
# 3 0.7121270600635369
# [0]	validation_0-rmse:7.61983
# [1000]	validation_0-rmse:0.71452
# [2000]	validation_0-rmse:0.71229
# [2875]	validation_0-rmse:0.71223
# [I 2021-08-25 13:42:11,073] Trial 18 finished with value: 0.7115134564218055 and parameters: {'n_estimators': 4185, 'learning_rate': 0.02150695086603378, 'reg_lambda': 0.0025184847547236947, 'reg_alpha': 3.343542448729039, 'subsample': 0.9391276589890923, 'colsample_bytree': 0.5250522983048288, 'max_depth': 5}. Best is trial 18 with value: 0.7115134564218055.
# 4 0.7120909457464938
# [0]	validation_0-rmse:7.41678
# [759]	validation_0-rmse:0.72969
# 0 0.7191274813822801
# [0]	validation_0-rmse:7.41331
# [1000]	validation_0-rmse:0.71788
# [1126]	validation_0-rmse:0.71831
# 1 0.7154137920752562
# [0]	validation_0-rmse:7.41100
# [554]	validation_0-rmse:0.72796
# 2 0.7233764312181014
# [0]	validation_0-rmse:7.41366
# [552]	validation_0-rmse:0.72610
# 3 0.7222057495155134
# [0]	validation_0-rmse:7.41888
# [865]	validation_0-rmse:0.72340
# [I 2021-08-25 13:43:02,308] Trial 19 finished with value: 0.7200875519635986 and parameters: {'n_estimators': 4169, 'learning_rate': 0.04754464534463367, 'reg_lambda': 0.00024176172377254982, 'reg_alpha': 0.0017126134916571499, 'subsample': 0.9081259274122813, 'colsample_bytree': 0.10523931564974914, 'max_depth': 3}. Best is trial 18 with value: 0.7115134564218055.
# 4 0.7203143056268421
# [0]	validation_0-rmse:7.19986
# [1000]	validation_0-rmse:0.71243
# [1566]	validation_0-rmse:0.71248
# 0 0.7122706055541191
# [0]	validation_0-rmse:7.19616
# [1000]	validation_0-rmse:0.71136
# [1153]	validation_0-rmse:0.71169
# 1 0.7108134727180474
# [0]	validation_0-rmse:7.19369
# [1000]	validation_0-rmse:0.71483
# [1020]	validation_0-rmse:0.71488
# 2 0.7144137526917655
# [0]	validation_0-rmse:7.19657
# [1000]	validation_0-rmse:0.71278
# [1116]	validation_0-rmse:0.71287
# 3 0.7127017883829998
# [0]	validation_0-rmse:7.20180
# [981]	validation_0-rmse:0.71403
# [I 2021-08-25 13:44:36,638] Trial 20 finished with value: 0.7125627037965858 and parameters: {'n_estimators': 6208, 'learning_rate': 0.07587407269272796, 'reg_lambda': 0.09295916773282276, 'reg_alpha': 3.065329463699019, 'subsample': 0.6802324454480673, 'colsample_bytree': 0.5343303864332093, 'max_depth': 4}. Best is trial 18 with value: 0.7115134564218055.
# 4 0.7126138996359973
# [0]	validation_0-rmse:7.11433
# [856]	validation_0-rmse:0.71205
# 0 0.7102500793829474
# [0]	validation_0-rmse:7.10978
# [743]	validation_0-rmse:0.71747
# 1 0.7120343079483645
# [0]	validation_0-rmse:7.10723
# [932]	validation_0-rmse:0.71768
# 2 0.714977079911469
# [0]	validation_0-rmse:7.11009
# [860]	validation_0-rmse:0.71947
# 3 0.7129062294558927
# [0]	validation_0-rmse:7.11543
# [779]	validation_0-rmse:0.71581
# [I 2021-08-25 13:45:50,922] Trial 21 finished with value: 0.7125327768470757 and parameters: {'n_estimators': 6576, 'learning_rate': 0.0870960941544812, 'reg_lambda': 0.06001635356224885, 'reg_alpha': 1.963623602631598, 'subsample': 0.6495473261981461, 'colsample_bytree': 0.5456169067066196, 'max_depth': 4}. Best is trial 18 with value: 0.7115134564218055.
# 4 0.7124961875367047
# [0]	validation_0-rmse:6.93302
# [654]	validation_0-rmse:0.71229
# 0 0.7107646097196691
# [0]	validation_0-rmse:6.92945
# [665]	validation_0-rmse:0.71518
# 1 0.7135077184666707
# [0]	validation_0-rmse:6.92698
# [565]	validation_0-rmse:0.72340
# 2 0.7154715524675626
# [0]	validation_0-rmse:6.92981
# [602]	validation_0-rmse:0.71939
# 3 0.7138307002188794
# [0]	validation_0-rmse:6.93526
# [644]	validation_0-rmse:0.72431
# [I 2021-08-25 13:46:42,556] Trial 22 finished with value: 0.7142920288249368 and parameters: {'n_estimators': 4416, 'learning_rate': 0.11058220306489486, 'reg_lambda': 1.6305222055204758, 'reg_alpha': 2.317334053766655, 'subsample': 0.7134620741707495, 'colsample_bytree': 0.5461714525559451, 'max_depth': 5}. Best is trial 18 with value: 0.7115134564218055.
# 4 0.717885563251902
# [0]	validation_0-rmse:7.36949
# [914]	validation_0-rmse:0.72012
# 0 0.7118210915674412
# [0]	validation_0-rmse:7.36558
# [869]	validation_0-rmse:0.71837
# 1 0.7131063089378291
# [0]	validation_0-rmse:7.36340
# [579]	validation_0-rmse:0.72603
# 2 0.7181895767129745
# [0]	validation_0-rmse:7.36625
# [630]	validation_0-rmse:0.73138
# 3 0.7172149879338671
# [0]	validation_0-rmse:7.37115
# [630]	validation_0-rmse:0.72484
# [I 2021-08-25 13:47:28,558] Trial 23 finished with value: 0.7155256252256293 and parameters: {'n_estimators': 6471, 'learning_rate': 0.053866030627717255, 'reg_lambda': 0.021486777098789604, 'reg_alpha': 0.43075237535436145, 'subsample': 0.47354518198398143, 'colsample_bytree': 0.37837071520753285, 'max_depth': 4}. Best is trial 18 with value: 0.7115134564218055.
# 4 0.7172961609760349
# [0]	validation_0-rmse:5.86331
# [442]	validation_0-rmse:0.74057
# 0 0.7127747015693231
# [0]	validation_0-rmse:5.86460
# [447]	validation_0-rmse:0.82771
# 1 0.7143174689117456
# [0]	validation_0-rmse:5.86251
# [415]	validation_0-rmse:0.78344
# 2 0.7181183873267502
# [0]	validation_0-rmse:5.86477
# [385]	validation_0-rmse:0.78021
# 3 0.7179162378737065
# [0]	validation_0-rmse:5.87134
# [432]	validation_0-rmse:0.82045
# [I 2021-08-25 13:47:56,949] Trial 24 finished with value: 0.7158658341227528 and parameters: {'n_estimators': 5650, 'learning_rate': 0.24929358354474934, 'reg_lambda': 0.0007207314005526508, 'reg_alpha': 0.003340476568881566, 'subsample': 0.6243210905440972, 'colsample_bytree': 0.7440314113657431, 'max_depth': 3}. Best is trial 18 with value: 0.7115134564218055.
# 4 0.7162023749322391
# [0]	validation_0-rmse:7.47232
# [1000]	validation_0-rmse:0.71879
# [2000]	validation_0-rmse:0.71732
# [2628]	validation_0-rmse:0.71741
# 0 0.7172576016283431
# [0]	validation_0-rmse:7.46885
# [1000]	validation_0-rmse:0.71419
# [2000]	validation_0-rmse:0.71313
# [2201]	validation_0-rmse:0.71319
# 1 0.7131040178613458
# [0]	validation_0-rmse:7.46657
# [1000]	validation_0-rmse:0.72323
# [2000]	validation_0-rmse:0.72212
# [2296]	validation_0-rmse:0.72228
# 2 0.7221108876170359
# [0]	validation_0-rmse:7.46920
# [1000]	validation_0-rmse:0.71891
# [2000]	validation_0-rmse:0.71826
# [2196]	validation_0-rmse:0.71825
# 3 0.7182328162351399
# [0]	validation_0-rmse:7.47443
# [1000]	validation_0-rmse:0.71950
# [2000]	validation_0-rmse:0.71823
# [2491]	validation_0-rmse:0.71839
# [I 2021-08-25 13:51:01,943] Trial 25 finished with value: 0.7177698215996479 and parameters: {'n_estimators': 2868, 'learning_rate': 0.04031646271204857, 'reg_lambda': 2.987976165476765, 'reg_alpha': 11.442855797869841, 'subsample': 0.8887561741939931, 'colsample_bytree': 0.6205838741257526, 'max_depth': 5}. Best is trial 18 with value: 0.7115134564218055.
# 4 0.7181437846563744
# [0]	validation_0-rmse:7.17360
# [910]	validation_0-rmse:0.71862
# 0 0.7116083552884491
# [0]	validation_0-rmse:7.17041
# [873]	validation_0-rmse:0.72098
# 1 0.7132885294635527
# [0]	validation_0-rmse:7.16829
# [630]	validation_0-rmse:0.72650
# 2 0.7173229223101959
# [0]	validation_0-rmse:7.17012
# [587]	validation_0-rmse:0.72388
# 3 0.7177441487986113
# [0]	validation_0-rmse:7.17547
# [755]	validation_0-rmse:0.73579
# [I 2021-08-25 13:51:43,543] Trial 26 finished with value: 0.7155240495475752 and parameters: {'n_estimators': 4707, 'learning_rate': 0.07929371095619259, 'reg_lambda': 1.5106069925723009e-05, 'reg_alpha': 0.5299836501851161, 'subsample': 0.4761661501484791, 'colsample_bytree': 0.5042039157938464, 'max_depth': 3}. Best is trial 18 with value: 0.7115134564218055.
# 4 0.7176562918770667
# [0]	validation_0-rmse:6.73846
# [993]	validation_0-rmse:0.71948
# 0 0.7188706899467946
# [0]	validation_0-rmse:6.73455
# [804]	validation_0-rmse:0.71090
# 1 0.7104763482418349
# [0]	validation_0-rmse:6.73222
# [1000]	validation_0-rmse:0.72165
# [1026]	validation_0-rmse:0.72166
# 2 0.7211817118271239
# [0]	validation_0-rmse:6.73506
# [1000]	validation_0-rmse:0.72022
# [1071]	validation_0-rmse:0.72047
# 3 0.7196487724915627
# [0]	validation_0-rmse:6.74047
# [864]	validation_0-rmse:0.71474
# [I 2021-08-25 13:52:47,699] Trial 27 finished with value: 0.7169075955205838 and parameters: {'n_estimators': 6727, 'learning_rate': 0.13563119374083502, 'reg_lambda': 44.12348651389438, 'reg_alpha': 6.8957915124655145, 'subsample': 0.7378096774155919, 'colsample_bytree': 0.5861104715798378, 'max_depth': 4}. Best is trial 18 with value: 0.7115134564218055.
# 4 0.714360455095603
# [0]	validation_0-rmse:7.62564
# [1000]	validation_0-rmse:0.71114
# [1497]	validation_0-rmse:0.71203
# 0 0.7109595912373134
# [0]	validation_0-rmse:7.62208
# [1000]	validation_0-rmse:0.71341
# [1565]	validation_0-rmse:0.71642
# 1 0.713124510098846
# [0]	validation_0-rmse:7.61986
# [1000]	validation_0-rmse:0.71659
# [1077]	validation_0-rmse:0.71658
# 2 0.7161939306333077
# [0]	validation_0-rmse:7.62256
# [1000]	validation_0-rmse:0.71510
# [1350]	validation_0-rmse:0.71752
# 3 0.7148630792401096
# [0]	validation_0-rmse:7.62775
# [1000]	validation_0-rmse:0.71461
# [1351]	validation_0-rmse:0.71603
# [I 2021-08-25 13:54:27,917] Trial 28 finished with value: 0.7139077633527291 and parameters: {'n_estimators': 5661, 'learning_rate': 0.020501352362434933, 'reg_lambda': 0.6230860998391387, 'reg_alpha': 0.014051003365705191, 'subsample': 0.6353169683309956, 'colsample_bytree': 0.3601735195735579, 'max_depth': 5}. Best is trial 18 with value: 0.7115134564218055.
# 4 0.7143977055540683
# [0]	validation_0-rmse:7.29206
# [470]	validation_0-rmse:0.71850
# 0 0.7140333647610855
# [0]	validation_0-rmse:7.28960
# [539]	validation_0-rmse:0.71676
# 1 0.7146230322519026
# [0]	validation_0-rmse:7.28710
# [411]	validation_0-rmse:0.73291
# 2 0.719517266261382
# [0]	validation_0-rmse:7.28988
# [453]	validation_0-rmse:0.72384
# 3 0.7172816626828833
# [0]	validation_0-rmse:7.29401
# [508]	validation_0-rmse:0.72915
# [I 2021-08-25 13:55:16,207] Trial 29 finished with value: 0.7164793608632396 and parameters: {'n_estimators': 7009, 'learning_rate': 0.0637339407122229, 'reg_lambda': 0.026833157675371935, 'reg_alpha': 0.47791973161154183, 'subsample': 0.5021856742291878, 'colsample_bytree': 0.7493599177312534, 'max_depth': 6}. Best is trial 18 with value: 0.7115134564218055.
# 4 0.7169414783589448

# %% [markdown]
# 0.7289161215950625  ordinal + stand   <br>
# 0.7359939686055645  ordinal + normalizer <br>
# 0.7339300282189536  ordinal + standard + normalizer <br>
# 0.7359933943841589  ordinal + normalizer +standard   <br>
# 0.7288775872910201  ohe + stand   <br>
# 0.7359376887794242   ohe + normalizer   <br>
# 0.7289403434752502 (ohe+ 3 ordinal) + stand   <br>
# 0.7291070689887855  poly3 (T,F) (ohe+ 1 ordinal) + stand   <br>
# 0.72914235959686  poly3 (F,F) (ohe+ 1 ordinal) + stand   <br>
# 0.728907008813998  poly2 (F,F) (ohe+ 1 ordinal) + stand   <br>
# 0.7289321289479873   poly2 (F,T) (ohe+ 1 ordinal) + stand   <br>
# 0.7289501787229472   poly2 (T,T) (ohe+ 1 ordinal) + stand   <br>
# 0.7289416327232601   poly2 (T,F) (ohe+ 1 ordinal) + stand   <br>
#
# 0.7288644838881868  (ohe+ 1 ordinal) + stand   <br>
# -0.7189543356528036   T_outliers+ (ohe+ 1 ordinal) + stand <br>
# 0.7205793549092518    T_encoding + T_outliers+ (ohe+ 1 ordinal) + stand <br>
#          opt + SVD encoding + T_encoding + T_outliers+ (ohe+ 1 ordinal) + stand <br>

# %%
study.best_params
# Out:
# {'n_estimators': 4185,
#  'learning_rate': 0.02150695086603378,
#  'reg_lambda': 0.0025184847547236947,
#  'reg_alpha': 3.343542448729039,
#  'subsample': 0.9391276589890923,
#  'colsample_bytree': 0.5250522983048288,
#  'max_depth': 5}

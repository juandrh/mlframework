# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import make_scorer
from xgboost import XGBRegressor, DMatrix

import matplotlib.pyplot as plt
# %matplotlib inline            
import seaborn as sns

from time import time
import pprint
import joblib
from functools import partial

# Suppressing warnings because of skopt verbosity
import warnings
warnings.filterwarnings("ignore")

# Skopt functions
from skopt import BayesSearchCV
from skopt.callbacks import DeadlineStopper, DeltaYStopper
from skopt.space import Real, Categorical, Integer

# Model selection
from sklearn.model_selection import KFold

import optuna


import lightgbm as lgb


from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
df = pd.read_csv("../input/train_folds.csv")
df_test = pd.read_csv("../input/test.csv")
sample_submission = pd.read_csv("../input/sample_submission.csv")

df = df.drop(df[df['target'].lt(6)].index)
print(df.shape)

useful_features = [c for c in df.columns if c not in ("id", "target", "kfold")]
object_cols = [col for col in useful_features if 'cat' in col]
numerical_cols = [col for col in useful_features if 'cont' in col]
df_test = df_test[useful_features]

# target encoding
for col in object_cols:
    temp_df = []
    temp_test_feat = None
    for fold in range(5):
        xtrain =  df[df.kfold != fold].reset_index(drop=True)
        xvalid = df[df.kfold == fold].reset_index(drop=True)
        feat = xtrain.groupby(col)["target"].agg("mean")
        feat = feat.to_dict()
        xvalid.loc[:, f"tar_enc_{col}"] = xvalid[col].map(feat)
        temp_df.append(xvalid)
        if temp_test_feat is None:
            temp_test_feat = df_test[col].map(feat)
        else:
            temp_test_feat += df_test[col].map(feat)
    
    temp_test_feat /= 5
    df_test.loc[:, f"tar_enc_{col}"] = temp_test_feat
    df = pd.concat(temp_df)

useful_features = [c for c in df.columns if c not in ("id", "target", "kfold")]
object_cols = [col for col in useful_features if col.startswith("cat")]
df_test = df_test[useful_features]

# Processing categoricals with SVD encoding
X_seq = df[object_cols].apply(lambda x: " ".join(list([str(y) + str(i) for i, y in enumerate(x)])), axis=1)
X_test_seq = df_test[object_cols].apply(lambda x: " ".join(list([str(y) + str(i) for i, y in enumerate(x)])), axis=1)


latent_dims = 24

svd_feats = ['svd_'+str(l) for l in range(latent_dims)]
vectorizer = TfidfVectorizer()

dim_reductio = TruncatedSVD(n_components=24, random_state=0)
df[svd_feats] =  dim_reductio.fit_transform(vectorizer.fit_transform(X_seq))
df_test[svd_feats] = dim_reductio.transform(vectorizer.transform(X_test_seq))


    
# Processing categoricals with frequency encoding
object_cols = [item for item in df.columns if 'cat' in item]

for cat in object_cols:
    counts = dict(df[cat].value_counts() / len(df))
    df[cat+'_freq'] = df[cat].replace(counts)
    df_test[cat+'_freq'] = df_test[cat].replace(counts)

frequencies = [cat+'_freq' for cat in object_cols]


useful_features = [c for c in df.columns if c not in ("id", "target", "kfold")]
# Out:
# (299628, 27)

# %%
def run(trial):

    n_estimators = trial.suggest_int("n_estimators", 30, 5000)
    learning_rate = trial.suggest_float("learning_rate", 0.01, 1.0, log=True)
    num_leaves = trial.suggest_int("num_leaves",2, 512)
    max_depth = trial.suggest_int("max_depth", -1, 256)
    subsample =  trial.suggest_loguniform("subsample",0.01, 1.0)
    subsample_freq = trial.suggest_int("subsample_freq",1, 10)
    colsample_bytree = trial.suggest_float("colsample_bytree", 0.01, 1.0)
    reg_lambda = trial.suggest_loguniform("reg_lambda", 1e-9, 100.0)
    reg_alpha = trial.suggest_loguniform("reg_alpha", 1e-9, 100.0)   
   


    final_predictions = []
    scores=[]
    for fold in range(5):
        xtrain =  df[df.kfold != fold].reset_index(drop=True)
        xvalid = df[df.kfold == fold].reset_index(drop=True)
        #xtest = df_test.copy()


        ytrain = xtrain.target
        yvalid = xvalid.target
        
        xtrain = xtrain[useful_features]
        xvalid = xvalid[useful_features]

    
        # standarization

        scaler = preprocessing.StandardScaler()
        xtrain[numerical_cols] = scaler.fit_transform(xtrain[numerical_cols])
        xvalid[numerical_cols] = scaler.transform(xvalid[numerical_cols])
        #xtest[numerical_cols] = scaler.transform(xtest[numerical_cols])

        
 
        # label encode columns 
        ordinal_encoder = preprocessing.OrdinalEncoder()
        xtrain[object_cols] = ordinal_encoder.fit_transform(xtrain[object_cols])
        xvalid[object_cols] = ordinal_encoder.fit_transform(xvalid[object_cols])
        #xtest[object_cols] = ordinal_encoder.fit_transform(xtest[object_cols])

        model= lgb.LGBMRegressor(boosting_type='gbdt',
                        metric='rmse',
                        n_jobs=-1, 
                        verbose= -1,
                        random_state=42,                        
                        learning_rate = learning_rate,
                        n_estimators = n_estimators,
                        num_leaves = num_leaves,
                        max_depth = max_depth,
                        subsample = subsample,
                        subsample_freq =subsample_freq,
                        colsample_bytree = colsample_bytree,
                        reg_lambda = reg_lambda,
                        reg_alpha = reg_alpha
                        )



   
        
        model.fit(xtrain, ytrain, early_stopping_rounds=300, eval_set=[(xvalid,yvalid)], verbose=1000)
        preds_valid = model.predict(xvalid)
        #test_preds = model.predict(after_OH_test)
        #final_predictions.append(test_preds)
        rmse = mean_squared_error(yvalid, preds_valid, squared=False)
        print(fold,rmse)
        scores.append(rmse)
        
    return np.mean(scores)

# %%
study = optuna.create_study(direction="minimize")
study.optimize(run, n_trials=100)
# Out:
# se: 0.711715
# [I 2021-08-25 20:27:08,385] Trial 69 finished with value: 0.7119099122105954 and parameters: {'n_estimators': 2426, 'learning_rate': 0.015861697487245596, 'num_leaves': 43, 'max_depth': 235, 'subsample': 0.5118270299260783, 'subsample_freq': 7, 'colsample_bytree': 0.1381134523618621, 'reg_lambda': 0.14231468025182525, 'reg_alpha': 1.0069797766480355e-08}. Best is trial 64 with value: 0.7116032045059005.
# 4 0.7117152934507938
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [261]	valid_0's rmse: 0.713416
# 0 0.7134156969471872
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [263]	valid_0's rmse: 0.713016
# 1 0.713015802134693
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [246]	valid_0's rmse: 0.71532
# 2 0.7153199263390909
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [260]	valid_0's rmse: 0.714352
# 3 0.7143517890933502
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [294]	valid_0's rmse: 0.713718
# [I 2021-08-25 20:27:44,649] Trial 70 finished with value: 0.7139641788247559 and parameters: {'n_estimators': 3359, 'learning_rate': 0.09831052322457427, 'num_leaves': 39, 'max_depth': 247, 'subsample': 0.4993135377988179, 'subsample_freq': 5, 'colsample_bytree': 0.13694339650615356, 'reg_lambda': 0.1369240972496316, 'reg_alpha': 1.0053837639115659e-08}. Best is trial 64 with value: 0.7116032045059005.
# 4 0.7137176796094585
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.712188
# [2000]	valid_0's rmse: 0.710065
# Did not meet early stopping. Best iteration is:
# [2301]	valid_0's rmse: 0.709917
# 0 0.7099174151383022
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.71379
# [2000]	valid_0's rmse: 0.711595
# Did not meet early stopping. Best iteration is:
# [2273]	valid_0's rmse: 0.711545
# 1 0.7115445230019665
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.715461
# [2000]	valid_0's rmse: 0.713984
# Early stopping, best iteration is:
# [1897]	valid_0's rmse: 0.713717
# 2 0.7137173982757075
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.715327
# [2000]	valid_0's rmse: 0.713802
# Early stopping, best iteration is:
# [1860]	valid_0's rmse: 0.713573
# 3 0.7135731513231339
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.715193
# [2000]	valid_0's rmse: 0.712961
# Did not meet early stopping. Best iteration is:
# [2375]	valid_0's rmse: 0.712672
# [I 2021-08-25 20:30:09,477] Trial 71 finished with value: 0.7122848329585123 and parameters: {'n_estimators': 2429, 'learning_rate': 0.01778596626892335, 'num_leaves': 63, 'max_depth': 234, 'subsample': 0.6114803628480464, 'subsample_freq': 7, 'colsample_bytree': 0.10362773898182617, 'reg_lambda': 0.30269675723959877, 'reg_alpha': 4.167799309990659e-09}. Best is trial 64 with value: 0.7116032045059005.
# 4 0.712671677053452
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.7206
# [2000]	valid_0's rmse: 0.717296
# Did not meet early stopping. Best iteration is:
# [2276]	valid_0's rmse: 0.716758
# 0 0.7167576083930771
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.722638
# [2000]	valid_0's rmse: 0.719335
# Did not meet early stopping. Best iteration is:
# [2276]	valid_0's rmse: 0.718735
# 1 0.7187350286914228
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.724491
# [2000]	valid_0's rmse: 0.72132
# Did not meet early stopping. Best iteration is:
# [2275]	valid_0's rmse: 0.720743
# 2 0.7207432613718894
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.723863
# [2000]	valid_0's rmse: 0.720556
# Did not meet early stopping. Best iteration is:
# [2276]	valid_0's rmse: 0.719955
# 3 0.7199553038802357
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.724383
# [2000]	valid_0's rmse: 0.720856
# Did not meet early stopping. Best iteration is:
# [2276]	valid_0's rmse: 0.72028
# [I 2021-08-25 20:31:49,924] Trial 72 finished with value: 0.7192942369358986 and parameters: {'n_estimators': 2276, 'learning_rate': 0.014854565832084441, 'num_leaves': 3, 'max_depth': 222, 'subsample': 0.8468610827296337, 'subsample_freq': 7, 'colsample_bytree': 0.2233562534280403, 'reg_lambda': 0.04048817577348744, 'reg_alpha': 5.635818900878038e-08}. Best is trial 64 with value: 0.7116032045059005.
# 4 0.7202799823428679
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.710154
# [2000]	valid_0's rmse: 0.709026
# Early stopping, best iteration is:
# [2380]	valid_0's rmse: 0.708966
# 0 0.7089660516409405
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.711859
# [2000]	valid_0's rmse: 0.710782
# Early stopping, best iteration is:
# [1930]	valid_0's rmse: 0.710757
# 1 0.7107572653068267
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.713752
# [2000]	valid_0's rmse: 0.712777
# Early stopping, best iteration is:
# [2095]	valid_0's rmse: 0.712763
# 2 0.7127634252933336
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.713307
# [2000]	valid_0's rmse: 0.712513
# Early stopping, best iteration is:
# [1787]	valid_0's rmse: 0.712466
# 3 0.712465765738088
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.712832
# [2000]	valid_0's rmse: 0.711512
# Early stopping, best iteration is:
# [2450]	valid_0's rmse: 0.711473
# [I 2021-08-25 20:41:11,440] Trial 73 finished with value: 0.711285191986663 and parameters: {'n_estimators': 2882, 'learning_rate': 0.0119798964707648, 'num_leaves': 118, 'max_depth': 236, 'subsample': 0.6844836827932818, 'subsample_freq': 9, 'colsample_bytree': 0.28009334474050396, 'reg_lambda': 0.09338343995087718, 'reg_alpha': 4.223298332097021}. Best is trial 73 with value: 0.711285191986663.
# 4 0.7114734519541259
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [16]	valid_0's rmse: 0.718149
# 0 0.7181486589659815
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [20]	valid_0's rmse: 0.71946
# 1 0.7194602967941564
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [25]	valid_0's rmse: 0.7209
# 2 0.7209004705299106
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [26]	valid_0's rmse: 0.720802
# 3 0.7208015339979121
# Training until validation scores don't improve for 300 rounds
# [I 2021-08-25 20:42:23,996] Trial 74 finished with value: 0.7200065840265162 and parameters: {'n_estimators': 2940, 'learning_rate': 0.9491114552589289, 'num_leaves': 49, 'max_depth': 238, 'subsample': 0.5052513396368712, 'subsample_freq': 10, 'colsample_bytree': 0.2844073574874599, 'reg_lambda': 25.433799199781507, 'reg_alpha': 93.42712539920689}. Best is trial 73 with value: 0.711285191986663.
# Early stopping, best iteration is:
# [30]	valid_0's rmse: 0.720722
# 4 0.7207219598446205
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.710828
# [2000]	valid_0's rmse: 0.709152
# Did not meet early stopping. Best iteration is:
# [2452]	valid_0's rmse: 0.708921
# 0 0.7089210983952505
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.712566
# [2000]	valid_0's rmse: 0.710909
# Did not meet early stopping. Best iteration is:
# [2683]	valid_0's rmse: 0.710737
# 1 0.7107372310124486
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.714565
# [2000]	valid_0's rmse: 0.713044
# Did not meet early stopping. Best iteration is:
# [2678]	valid_0's rmse: 0.712883
# 2 0.7128831267675745
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.713897
# [2000]	valid_0's rmse: 0.71219
# Did not meet early stopping. Best iteration is:
# [2444]	valid_0's rmse: 0.712076
# 3 0.7120760453495131
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.713701
# [2000]	valid_0's rmse: 0.711812
# Did not meet early stopping. Best iteration is:
# [2673]	valid_0's rmse: 0.711553
# [I 2021-08-25 20:55:08,336] Trial 75 finished with value: 0.7112341820655568 and parameters: {'n_estimators': 2683, 'learning_rate': 0.010250629304555186, 'num_leaves': 79, 'max_depth': 256, 'subsample': 0.7778732709684482, 'subsample_freq': 9, 'colsample_bytree': 0.35917838955653647, 'reg_lambda': 2.943257012154159, 'reg_alpha': 2.416846681288718}. Best is trial 75 with value: 0.7112341820655568.
# 4 0.7115534088029974
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.717438
# Early stopping, best iteration is:
# [978]	valid_0's rmse: 0.717413
# 0 0.717412805584171
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.719522
# Early stopping, best iteration is:
# [1110]	valid_0's rmse: 0.719353
# 1 0.7193534285559123
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.721097
# Early stopping, best iteration is:
# [1396]	valid_0's rmse: 0.720593
# 2 0.7205928790359514
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.720824
# Early stopping, best iteration is:
# [1215]	valid_0's rmse: 0.720367
# 3 0.720367342514446
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.720865
# Early stopping, best iteration is:
# [1573]	valid_0's rmse: 0.720186
# [I 2021-08-25 20:59:46,211] Trial 76 finished with value: 0.7195825044149153 and parameters: {'n_estimators': 3108, 'learning_rate': 0.01059431677821872, 'num_leaves': 87, 'max_depth': 256, 'subsample': 0.029543739402369998, 'subsample_freq': 9, 'colsample_bytree': 0.37111775458229335, 'reg_lambda': 1.540638195601805, 'reg_alpha': 6.314065465980496}. Best is trial 75 with value: 0.7112341820655568.
# 4 0.7201860663840961
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [122]	valid_0's rmse: 0.711023
# 0 0.7110234959947376
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [112]	valid_0's rmse: 0.712251
# 1 0.7122510039329054
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [125]	valid_0's rmse: 0.714647
# 2 0.7146472917710158
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [125]	valid_0's rmse: 0.714774
# 3 0.7147737268839918
# Training until validation scores don't improve for 300 rounds
# [I 2021-08-25 21:01:18,523] Trial 77 finished with value: 0.7133922930933817 and parameters: {'n_estimators': 3242, 'learning_rate': 0.2559319939774537, 'num_leaves': 23, 'max_depth': 57, 'subsample': 0.7755879359180182, 'subsample_freq': 9, 'colsample_bytree': 0.5423849302332787, 'reg_lambda': 3.6727957425658184, 'reg_alpha': 9.469957049134962}. Best is trial 75 with value: 0.7112341820655568.
# Early stopping, best iteration is:
# [154]	valid_0's rmse: 0.714266
# 4 0.7142659468842579
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.714601
# Early stopping, best iteration is:
# [839]	valid_0's rmse: 0.714403
# 0 0.7144034270633851
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.717113
# Early stopping, best iteration is:
# [897]	valid_0's rmse: 0.716964
# 1 0.7169639740008431
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.719074
# Early stopping, best iteration is:
# [1011]	valid_0's rmse: 0.71904
# 2 0.7190400220682789
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.718676
# Early stopping, best iteration is:
# [858]	valid_0's rmse: 0.718563
# 3 0.71856298483311
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.717703
# Early stopping, best iteration is:
# [1117]	valid_0's rmse: 0.71759
# [I 2021-08-25 21:07:02,547] Trial 78 finished with value: 0.717312038761635 and parameters: {'n_estimators': 2766, 'learning_rate': 0.013037809133643231, 'num_leaves': 117, 'max_depth': 245, 'subsample': 0.07993774022443238, 'subsample_freq': 9, 'colsample_bytree': 0.41921852566199164, 'reg_lambda': 0.1319780527576954, 'reg_alpha': 2.9301275063950003}. Best is trial 75 with value: 0.7112341820655568.
# 4 0.7175897858425576
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.710787
# Early stopping, best iteration is:
# [1287]	valid_0's rmse: 0.710411
# 0 0.7104112016172918
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.712822
# Early stopping, best iteration is:
# [1291]	valid_0's rmse: 0.712572
# 1 0.7125719975577198
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.714641
# Early stopping, best iteration is:
# [1329]	valid_0's rmse: 0.71455
# 2 0.7145501986971564
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.714229
# Early stopping, best iteration is:
# [1166]	valid_0's rmse: 0.714052
# 3 0.7140524213316652
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.713421
# Early stopping, best iteration is:
# [1383]	valid_0's rmse: 0.713093
# [I 2021-08-25 21:32:41,541] Trial 79 finished with value: 0.7129357450095892 and parameters: {'n_estimators': 2645, 'learning_rate': 0.01143242372237565, 'num_leaves': 389, 'max_depth': 219, 'subsample': 0.6606597908378772, 'subsample_freq': 8, 'colsample_bytree': 0.33758893913122867, 'reg_lambda': 17.54325832957484, 'reg_alpha': 0.0587165620344938}. Best is trial 75 with value: 0.7112341820655568.
# 4 0.7130929058441124
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.709363
# Early stopping, best iteration is:
# [1459]	valid_0's rmse: 0.708886
# 0 0.7088859771006097
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.711208
# Early stopping, best iteration is:
# [1567]	valid_0's rmse: 0.71077
# 1 0.7107698461708631
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.713399
# Early stopping, best iteration is:
# [1163]	valid_0's rmse: 0.713227
# 2 0.7132268702197259
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.71253
# Early stopping, best iteration is:
# [1536]	valid_0's rmse: 0.712006
# 3 0.7120059153120528
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.711882
# Early stopping, best iteration is:
# [1371]	valid_0's rmse: 0.711439
# [I 2021-08-25 21:43:49,110] Trial 80 finished with value: 0.7112654551631407 and parameters: {'n_estimators': 3581, 'learning_rate': 0.019284623623057207, 'num_leaves': 57, 'max_depth': 250, 'subsample': 0.8584239979517946, 'subsample_freq': 8, 'colsample_bytree': 0.2693499654427011, 'reg_lambda': 0.6796563703406648, 'reg_alpha': 0.8875549983038465}. Best is trial 75 with value: 0.7112341820655568.
# 4 0.7114386670124517
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.709563
# Early stopping, best iteration is:
# [839]	valid_0's rmse: 0.709458
# 0 0.7094584834386559
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.711257
# Early stopping, best iteration is:
# [976]	valid_0's rmse: 0.711131
# 1 0.7111308694444229
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.713786
# Early stopping, best iteration is:
# [903]	valid_0's rmse: 0.713669
# 2 0.7136686667159248
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.712547
# Early stopping, best iteration is:
# [899]	valid_0's rmse: 0.712542
# 3 0.7125421436531414
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.712426
# Early stopping, best iteration is:
# [780]	valid_0's rmse: 0.712127
# [I 2021-08-25 21:51:32,619] Trial 81 finished with value: 0.7117854326051373 and parameters: {'n_estimators': 3696, 'learning_rate': 0.028509584287405097, 'num_leaves': 59, 'max_depth': 250, 'subsample': 0.893923316803085, 'subsample_freq': 8, 'colsample_bytree': 0.3222928911143421, 'reg_lambda': 0.45969721978826733, 'reg_alpha': 0.5096569863644471}. Best is trial 75 with value: 0.7112341820655568.
# 4 0.7121269997735412
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.709288
# Early stopping, best iteration is:
# [1109]	valid_0's rmse: 0.709163
# 0 0.7091630700142028
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.71114
# Early stopping, best iteration is:
# [1564]	valid_0's rmse: 0.710911
# 1 0.7109110589533821
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.713302
# Early stopping, best iteration is:
# [1014]	valid_0's rmse: 0.713285
# 2 0.7132846735223773
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.71235
# Early stopping, best iteration is:
# [1257]	valid_0's rmse: 0.712257
# 3 0.7122567846157751
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.712001
# Early stopping, best iteration is:
# [1235]	valid_0's rmse: 0.71184
# [I 2021-08-25 22:03:07,908] Trial 82 finished with value: 0.7114910764647392 and parameters: {'n_estimators': 3832, 'learning_rate': 0.021656936422980732, 'num_leaves': 62, 'max_depth': 251, 'subsample': 0.8302772505221798, 'subsample_freq': 8, 'colsample_bytree': 0.3071640815917457, 'reg_lambda': 0.5091862765922313, 'reg_alpha': 1.5111285970520691}. Best is trial 75 with value: 0.7112341820655568.
# 4 0.7118397952179586
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.709349
# Early stopping, best iteration is:
# [1316]	valid_0's rmse: 0.709298
# 0 0.7092984776165496
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.711143
# Early stopping, best iteration is:
# [1165]	valid_0's rmse: 0.71106
# 1 0.7110602625914463
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.713376
# Early stopping, best iteration is:
# [799]	valid_0's rmse: 0.713247
# 2 0.7132473312932507
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.712557
# Early stopping, best iteration is:
# [1012]	valid_0's rmse: 0.712533
# 3 0.7125333234641554
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.711916
# Early stopping, best iteration is:
# [1104]	valid_0's rmse: 0.711806
# [I 2021-08-25 22:12:58,721] Trial 83 finished with value: 0.711589068532368 and parameters: {'n_estimators': 3732, 'learning_rate': 0.028808491076707254, 'num_leaves': 65, 'max_depth': 251, 'subsample': 0.8985817488485087, 'subsample_freq': 8, 'colsample_bytree': 0.30758328150630593, 'reg_lambda': 0.717628680778469, 'reg_alpha': 1.1304289533820688}. Best is trial 75 with value: 0.7112341820655568.
# 4 0.711805947696438
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.709462
# Early stopping, best iteration is:
# [902]	valid_0's rmse: 0.70934
# 0 0.7093402351571927
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.711178
# Early stopping, best iteration is:
# [957]	valid_0's rmse: 0.711116
# 1 0.711115609721883
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.714062
# Early stopping, best iteration is:
# [748]	valid_0's rmse: 0.713617
# 2 0.7136173833904152
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.712673
# Early stopping, best iteration is:
# [765]	valid_0's rmse: 0.712525
# 3 0.7125252600039703
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12229/2760568937.py in <module>
#       1 study = optuna.create_study(direction="minimize")
# ----> 2 study.optimize(run, n_trials=100)
#       3
#
# ~/.local/lib/python3.8/site-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     398             )
#     399
# --> 400         _optimize(
#     401             study=self,
#     402             func=func,
#
# ~/.local/lib/python3.8/site-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64     try:
#      65         if n_jobs == 1:
# ---> 66             _optimize_sequential(
#      67                 study,
#      68                 func,
#
# ~/.local/lib/python3.8/site-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161
#     162         try:
# --> 163             trial = _run_trial(study, func, catch)
#     164         except Exception:
#     165             raise
#
# ~/.local/lib/python3.8/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     211
#     212     try:
# --> 213         value_or_values = func(trial)
#     214     except exceptions.TrialPruned as e:
#     215         # TODO(mamu): Handle multi-objective cases.
#
# /tmp/ipykernel_12229/1064072657.py in run(trial)
#      63
#      64
# ---> 65         model.fit(xtrain, ytrain, early_stopping_rounds=300, eval_set=[(xvalid,yvalid)], verbose=1000)
#      66         preds_valid = model.predict(xvalid)
#      67         #test_preds = model.predict(after_OH_test)
#
# ~/.local/lib/python3.8/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     816             callbacks=None, init_model=None):
#     817         """Docstring is inherited from the LGBMModel."""
# --> 818         super().fit(X, y, sample_weight=sample_weight, init_score=init_score,
#     819                     eval_set=eval_set, eval_names=eval_names, eval_sample_weight=eval_sample_weight,
#     820                     eval_init_score=eval_init_score, eval_metric=eval_metric,
#
# ~/.local/lib/python3.8/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     681             init_model = init_model.booster_
#     682
# --> 683         self._Booster = train(params, train_set,
#     684                               self.n_estimators, valid_sets=valid_sets, valid_names=eval_names,
#     685                               early_stopping_rounds=early_stopping_rounds,
#
# ~/.local/lib/python3.8/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     226     # construct booster
#     227     try:
# --> 228         booster = Booster(params=params, train_set=train_set)
#     229         if is_valid_contain_train:
#     230             booster.set_train_data_name(train_data_name)
#
# ~/.local/lib/python3.8/site-packages/lightgbm/basic.py in __init__(self, params, train_set, model_file, model_str, silent)
#    2227                 )
#    2228             # construct booster object
# -> 2229             train_set.construct()
#    2230             # copy the parameters from train_set
#    2231             params.update(train_set.get_params())
#
# ~/.local/lib/python3.8/site-packages/lightgbm/basic.py in construct(self)
#    1466             else:
#    1467                 # create train
# -> 1468                 self._lazy_init(self.data, label=self.label,
#    1469                                 weight=self.weight, group=self.group,
#    1470                                 init_score=self.init_score, predictor=self._predictor,
#
# ~/.local/lib/python3.8/site-packages/lightgbm/basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#    1207             self.pandas_categorical = reference.pandas_categorical
#    1208             categorical_feature = reference.categorical_feature
# -> 1209         data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(data,
#    1210                                                                                              feature_name,
#    1211                                                                                              categorical_feature,
#
# ~/.local/lib/python3.8/site-packages/lightgbm/basic.py in _data_from_pandas(data, feature_name, categorical_feature, pandas_categorical)
#     511         if feature_name == 'auto' or feature_name is None:
#     512             data = data.rename(columns=str)
# --> 513         cat_cols = list(data.select_dtypes(include=['category']).columns)
#     514         cat_cols_not_ordered = [col for col in cat_cols if not data[col].cat.ordered]
#     515         if pandas_categorical is None:  # train dataset
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in select_dtypes(self, include, exclude)
#    4352
#    4353         # error: "ndarray" has no attribute "values"
# -> 4354         return self.iloc[:, keep_these.values]  # type: ignore[attr-defined]
#    4355
#    4356     def insert(self, loc, column, value, allow_duplicates: bool = False) -> None:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1508             return self._getitem_lowerdim(tup)
#    1509
# -> 1510         return self._getitem_tuple_same_dim(tup)
#    1511
#    1512     def _get_list_axis(self, key, axis: int):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     804                 continue
#     805
# --> 806             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     807             # We should never have retval.ndim < self.ndim, as that should
#     808             #  be handled by the _getitem_lowerdim call above.
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1551         if com.is_bool_indexer(key):
#    1552             self._validate_key(key, axis)
# -> 1553             return self._getbool_axis(key, axis=axis)
#    1554
#    1555         # a list of integers
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _getbool_axis(self, key, axis)
#     948         key = check_bool_indexer(labels, key)
#     949         inds = key.nonzero()[0]
# --> 950         return self.obj._take_with_is_copy(inds, axis=axis)
#     951
#     952
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis)
#    3623         See the docstring of `take` for full explanation of the parameters.
#    3624         """
# -> 3625         result = self.take(indices=indices, axis=axis)
#    3626         # Maybe set copy if we didn't actually change the index.
#    3627         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3608         nv.validate_take((), kwargs)
#    3609
# -> 3610         self._consolidate_inplace()
#    3611
#    3612         new_data = self._mgr.take(
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in _consolidate_inplace(self)
#    5554             self._mgr = self._mgr.consolidate()
#    5555
# -> 5556         self._protect_consolidate(f)
#    5557
#    5558     @final
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in _protect_consolidate(self, f)
#    5542             return f()
#    5543         blocks_before = len(self._mgr.blocks)
# -> 5544         result = f()
#    5545         if len(self._mgr.blocks) != blocks_before:
#    5546             self._clear_item_cache()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in f()
#    5552
#    5553         def f():
# -> 5554             self._mgr = self._mgr.consolidate()
#    5555
#    5556         self._protect_consolidate(f)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py in consolidate(self)
#     610         bm = type(self)(self.blocks, self.axes, verify_integrity=False)
#     611         bm._is_consolidated = False
# --> 612         bm._consolidate_inplace()
#     613         return bm
#     614
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py in _consolidate_inplace(self)
#     615     def _consolidate_inplace(self) -> None:
#     616         if not self.is_consolidated():
# --> 617             self.blocks = tuple(_consolidate(self.blocks))
#     618             self._is_consolidated = True
#     619             self._known_consolidated = True
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py in _consolidate(blocks)
#    1965     new_blocks: list[Block] = []
#    1966     for (_can_consolidate, dtype), group_blocks in grouper:
# -> 1967         merged_blocks = _merge_blocks(
#    1968             list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    1969         )
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py in _merge_blocks(blocks, dtype, can_consolidate)
#    1999
#    2000         argsort = np.argsort(new_mgr_locs)
# -> 2001         new_values = new_values[argsort]
#    2002         new_mgr_locs = new_mgr_locs[argsort]
#    2003
#
# KeyboardInterrupt:

# %% [markdown]
# 0.7289161215950625  ordinal + stand   <br>
# 0.7359939686055645  ordinal + normalizer <br>
# 0.7339300282189536  ordinal + standard + normalizer <br>
# 0.7359933943841589  ordinal + normalizer +standard   <br>
# 0.7288775872910201  ohe + stand   <br>
# 0.7359376887794242   ohe + normalizer   <br>
# 0.7289403434752502 (ohe+ 3 ordinal) + stand   <br>
# 0.7291070689887855  poly3 (T,F) (ohe+ 1 ordinal) + stand   <br>
# 0.72914235959686  poly3 (F,F) (ohe+ 1 ordinal) + stand   <br>
# 0.728907008813998  poly2 (F,F) (ohe+ 1 ordinal) + stand   <br>
# 0.7289321289479873   poly2 (F,T) (ohe+ 1 ordinal) + stand   <br>
# 0.7289501787229472   poly2 (T,T) (ohe+ 1 ordinal) + stand   <br>
# 0.7289416327232601   poly2 (T,F) (ohe+ 1 ordinal) + stand   <br>
#
# 0.7288644838881868  (ohe+ 1 ordinal) + stand   <br>
# -0.7189543356528036   T_outliers+ (ohe+ 1 ordinal) + stand <br>
# 0.7205793549092518    T_encoding + T_outliers+ (ohe+ 1 ordinal) + stand <br>
#          opt + SVD encoding + T_encoding + T_outliers+ (ohe+ 1 ordinal) + stand <br>

# %%
study.best_params
# Out:
# {'n_estimators': 2683,
#  'learning_rate': 0.010250629304555186,
#  'num_leaves': 79,
#  'max_depth': 256,
#  'subsample': 0.7778732709684482,
#  'subsample_freq': 9,
#  'colsample_bytree': 0.35917838955653647,
#  'reg_lambda': 2.943257012154159,
#  'reg_alpha': 2.416846681288718}
